# %%
import pandas as pd
df = pd.read_excel("https://docs.google.com/spreadsheets/d/e/2PACX-1vR8AS4LnU66VOzeH0nz6Vbfrw2wQ0xAipWOgwjl81fln6ihf-bXdZ-DvGFXg-ufsFyNSy120q2uPaJT/pub?output=xlsx", sheet_name="Resultados_Clase1")
df
# Out:
#      Nombre del mentor o mentora        Zona              Sede         Bloque  \
# 0          Adrian Pineda Sanchez  Zona norte  DIF Pueblo Nuevo  Primera clase
# 1                            NaN         NaN               NaN            NaN
# 2                            NaN         NaN               NaN            NaN
# 3                            NaN         NaN               NaN            NaN
# 4                            NaN         NaN               NaN            NaN
# ...                          ...         ...               ...            ...
# 3180                         NaN         NaN               NaN            NaN
# 3181                         NaN         NaN               NaN            NaN
# 3182                         NaN         NaN               NaN            NaN
# 3183                         NaN         NaN               NaN            NaN
# 3184                         NaN         NaN               NaN            NaN
#
#                       Grado Número de semana Nombre del estudiante  \
# 0     Primero de secundaria         Semana 3                   NaN
# 1                       NaN              NaN                   NaN
# 2                       NaN              NaN                   NaN
# 3                       NaN              NaN                   NaN
# 4                       NaN              NaN                   NaN
# ...                     ...              ...                   ...
# 3180                    NaN              NaN                   NaN
# 3181                    NaN              NaN                   NaN
# 3182                    NaN              NaN                   NaN
# 3183                    NaN              NaN                   NaN
# 3184                    NaN              NaN                     1
#
#       ¿Realizó la actividad semanal?  Total de aciertos  Total de preguntas  \
# 0                                0.0                NaN                 NaN
# 1                                NaN                NaN                 NaN
# 2                                NaN                NaN                 NaN
# 3                                NaN                NaN                 NaN
# 4                                NaN                NaN                 NaN
# ...                              ...                ...                 ...
# 3180                             NaN                NaN                 NaN
# 3181                             NaN                NaN                 NaN
# 3182                             NaN                NaN                 NaN
# 3183                             NaN                NaN                 NaN
# 3184                             NaN                NaN                 NaN
#
#                          Último tema visto Comentario sobre el avance
# 0     S3_Sumar y restar números racionales                        NaN
# 1                                      NaN                        NaN
# 2                                      NaN                        NaN
# 3                                      NaN                        NaN
# 4                                      NaN                        NaN
# ...                                    ...                        ...
# 3180                                   NaN                        NaN
# 3181                                   NaN                        NaN
# 3182                                   NaN                        NaN
# 3183                                   NaN                        NaN
# 3184                                   NaN                        NaN
#
# [3185 rows x 12 columns]

# %%
df.dropna(how='all', inplace = True)
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#           Nombre del mentor o mentora         Zona                      Sede  \
# 0               Adrian Pineda Sanchez   Zona norte          DIF Pueblo Nuevo
# 1          Andrea Berenice López Cruz   Zona norte          DIF Pueblo Nuevo
# 2             Ángel David Ávila Pérez   Zona norte          DIF Pueblo Nuevo
# 3             Aranza Carrillo Márquez   Zona norte          DIF Pueblo Nuevo
# 4    Arnulfo Alejandro Morales Guzmán   Zona norte           Artemio Treviño
# ..                                ...          ...                       ...
# 192       Kevin Antonio González Díaz  Zona centro  Dirección de la Juventud
# 193       Kevin Antonio González Díaz  Zona centro  Dirección de la Juventud
# 194       Kevin Antonio González Díaz  Zona centro  Dirección de la Juventud
# 195       Kevin Antonio González Díaz  Zona centro  Dirección de la Juventud
# 196                               NaN          NaN                       NaN
#
#             Bloque                  Grado Número de semana  \
# 0    Primera clase  Primero de secundaria         Semana 3
# 1    Primera clase  Primero de secundaria         Semana 3
# 2    Primera clase  Primero de secundaria         Semana 3
# 3    Primera clase  Primero de secundaria         Semana 3
# 4    Primera clase  Primero de secundaria         Semana 3
# ..             ...                    ...              ...
# 192  Primera clase  Tercero de secundaria         Semana 5
# 193  Primera clase  Tercero de secundaria         Semana 5
# 194  Primera clase  Tercero de secundaria         Semana 5
# 195  Primera clase  Tercero de secundaria         Semana 5
# 196            NaN                    NaN              NaN
#
#               Nombre del estudiante  ¿Realizó la actividad semanal?  \
# 0                               NaN                             0.0
# 1                               NaN                             0.0
# 2                               NaN                             0.0
# 3                               NaN                             0.0
# 4                               NaN                             0.0
# ..                              ...                             ...
# 192        LUIS ANGEL VÁZQUEZ LUCAS                             1.0
# 193  ANGEL EDUARDO MARINES MARTINEZ                             0.0
# 194          MAYA NAOMI OCHOA AVILA                             1.0
# 195           PRICILA LOZANO VARGAS                             0.0
# 196                               1                             NaN
#
#      Total de aciertos  Total de preguntas  \
# 0                  NaN                 NaN
# 1                  NaN                 NaN
# 2                  NaN                 NaN
# 3                  NaN                 NaN
# 4                  NaN                 NaN
# ..                 ...                 ...
# 192               10.0                10.0
# 193                NaN                10.0
# 194                9.0                10.0
# 195                NaN                10.0
# 196                NaN                 NaN
#
#                         Último tema visto Comentario sobre el avance
# 0    S3_Sumar y restar números racionales                        NaN
# 1    S3_Sumar y restar números racionales                        NaN
# 2    S3_Sumar y restar números racionales                        NaN
# 3    S3_Sumar y restar números racionales                        NaN
# 4    S3_Sumar y restar números racionales                        NaN
# ..                                    ...                        ...
# 192               S5_Multiplicar binomios                        NaN
# 193               S5_Multiplicar binomios                        NaN
# 194               S5_Multiplicar binomios                        NaN
# 195               S5_Multiplicar binomios                        NaN
# 196                                   NaN                        NaN
#
# [197 rows x 12 columns]

# %%
# Resultados de la clase 1
df_links = pd.read_excel("https://docs.google.com/spreadsheets/d/e/2PACX-1vR8AS4LnU66VOzeH0nz6Vbfrw2wQ0xAipWOgwjl81fln6ihf-bXdZ-DvGFXg-ufsFyNSy120q2uPaJT/pub?output=xlsx", sheet_name="Links de Quizizz")
df_links.dropna(how='all', inplace = True)
df_links.reset_index(drop=True, inplace=True)
